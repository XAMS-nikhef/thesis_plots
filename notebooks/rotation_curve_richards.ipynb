# %%
import thesis_plots
import matplotlib.pyplot as plt

# %%
thesis_plots.setup_plt()

# %%
plt.figure(figsize=(9, 5))
thesis_plots.PlotRotationCurveRichards().plot()
thesis_plots.save_fig('rotation_curve_richards')

# %%
bla = plt.cm.cividis.copy()

# %%
bla??

# %%
bla._resample(10)
