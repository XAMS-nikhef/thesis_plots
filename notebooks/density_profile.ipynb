# %%
import thesis_plots
thesis_plots.setup_plt()

# %%
# thesis_plots.density_profile.plot_nfw(r_s=4)
thesis_plots.density_profile.plot_nfw(r_s=1)
thesis_plots.density_profile.plt.yscale('log')
# Out:
# /home/joran/software/thesis_clean/thesis_plots/density_profile/density_profile.py:7: RuntimeWarning: divide by zero encountered in true_divide
#   return rho_0 * r_s ** 3 / (r * (r + r_s) ** 2)

# %%
import numpy

# %%
ran = numpy.random.poisson(2.3, 100000000)

# %%
numpy.sum(ran<1)/len(ran)
# Out:
# 0.10020197
