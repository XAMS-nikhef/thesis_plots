# %%
import thesis_plots
thesis_plots.setup_plt()

# %%
thesis_plots.setup_plt()
thesis_plots.print_versions(
    'thesis_plots wimprates'.split(),
    return_string=False,
    print_output=False,
    )
# Out:
#          module version                                            path  \
# 0        python  3.10.4          /home/joran/yes/envs/py3.10/bin/python
# 1  thesis_plots   1.0.2  /home/joran/software/thesis_clean/thesis_plots
# 2     wimprates   0.4.1  /home/joran/software/wimprates_clean/wimprates
#
#                                  git
# 0                               None
# 1            branch:master | b3e5c2d
# 2  branch:fix_hardcoded_v0 | dc84cbd

# %%
thesis_plots.RecoilRatesPlot??

# %%
b=thesis_plots.RecoilRatesPlot()

# %%
b.plot_recoil_rates()
thesis_plots.save_fig('recoil_rates')

# %%
b.plot_velocities()
thesis_plots.save_fig('velocities')
# Out:
# /home/joran/software/wimprates_clean/wimprates/halo.py:168: RuntimeWarning: divide by zero encountered in true_divide
#   (v_esc**2 - v_earth_t**2 - v**2)
