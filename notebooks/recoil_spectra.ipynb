# %%
import thesis_plots
thesis_plots.setup_plt()

# %%
b=thesis_plots.RecoilRatesPlot()
b.color_map='custom_map_r'

# %%
# %%time
b.plot_velocities(annotate_mw_enr = (5, 1),
                 )
thesis_plots.save_fig('velocities')
# Out:
# /home/joran/software/wimprates_clean/wimprates/halo.py:168: RuntimeWarning: divide by zero encountered in true_divide
#   (v_esc**2 - v_earth_t**2 - v**2)
# Si 258.2855485829234
# Ar 293.3625170371373
# Ge 374.5009501457645
# Xe 488.00713795155576
# CPU times: user 3.9 s, sys: 882 ms, total: 4.78 s
# Wall time: 3.22 s

# %%
# %%time
b.plot_recoil_rates()
thesis_plots.save_fig('recoil_rates')
# Out:
# CPU times: user 3min 15s, sys: 749 ms, total: 3min 16s
# Wall time: 3min 15s
