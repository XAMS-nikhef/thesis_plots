# %%
import thesis_plots
thesis_plots.setup_plt()

# %%
b=thesis_plots.RecoilRatesPlot()

# %%
b.plot_recoil_rates()
thesis_plots.save_fig('recoil_rates')

# %%
b.plot_velocities()
thesis_plots.save_fig('velocities')
# Out:
# /home/joran/software/wimprates_clean/wimprates/halo.py:160: RuntimeWarning: divide by zero encountered in true_divide
#   (v_esc**2 - v_earth_t**2 - v**2)
